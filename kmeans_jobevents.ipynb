# %%
from glob import glob
import pandas as pd
import csv
from pandas import read_csv
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('/home/ubuntu/merged_files/kmeans_job_events.csv')

# %%
df1
# Out:
#             job ID  event type  scheduling class
# 0       6486215124           4                 1
# 1       6486208376           4                 2
# 2       6486208454           5                 0
# 3       6486208583           5                 2
# 4       6486201135           4                 2
# 5       6486201193           5                 0
# 6       6486201261           5                 2
# 7       6486157353           4                 0
# 8       6486215143           4                 1
# 9       6486215873           4                 2
# 10      6486215919           5                 0
# 11      6486215957           5                 2
# 12      6486217697           4                 0
# 13      6486211871           3                 1
# 14      6486216925           3                 1
# 15      6486217710           4                 0
# 16      6486216510           3                 1
# 17      6486213003           4                 1
# ...

# %%
df1= df1.rename(columns={'job ID': 'job_ID', 'event type': 'event_type', 'scheduling class': 'scheduling_class'})

# %%
df1
# Out:
#             job_ID  event_type  scheduling_class
# 0       6486215124           4                 1
# 1       6486208376           4                 2
# 2       6486208454           5                 0
# 3       6486208583           5                 2
# 4       6486201135           4                 2
# 5       6486201193           5                 0
# 6       6486201261           5                 2
# 7       6486157353           4                 0
# 8       6486215143           4                 1
# 9       6486215873           4                 2
# 10      6486215919           5                 0
# 11      6486215957           5                 2
# 12      6486217697           4                 0
# 13      6486211871           3                 1
# 14      6486216925           3                 1
# 15      6486217710           4                 0
# 16      6486216510           3                 1
# 17      6486213003           4                 1
# ...

# %%
kmeans=KMeans(n_clusters=6)
kmeans.fit(df1)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[6.45774010e+09 4.39160921e+00 9.19840730e-01]
#  [6.27941970e+09 4.38010393e+00 8.88032206e-01]
#  [3.37825445e+09 4.95652174e+00 2.27173913e+00]
#  [6.34351520e+09 4.38552695e+00 8.91464740e-01]
#  [5.31526248e+09 4.85660377e+00 1.59622642e+00]
#  [6.40069945e+09 4.40841089e+00 9.60240096e-01]]

# %%
print(kmeans.labels_)
# Out:
# [0 0 0 ... 1 4 1]

# %%
a=kmeans.labels_

# %%
a
# Out:
# array([0, 0, 0, ..., 1, 4, 1], dtype=int32)

# %%
{i: np.where(kmeans.labels_ == i)[0] for i in range(kmeans.n_clusters)}
# Out:
# {0: array([     0,      1,      2, ..., 155579, 155580, 155581]),
#  1: array([  2062,  16612,  27006, ..., 730721, 730722, 730724]),
#  2: array([ 98107, 108673, 115908, 139790, 151751, 159697, 159698, 296690,
#         296828, 331309, 331836, 334628, 334629, 345784, 345785, 345791,
#         350254, 399499, 424116, 426764, 428519, 429532, 429533, 442745,
#         479703, 540433, 556110, 556111, 556116, 556117, 556118, 556582,
#         563401, 580185, 596328, 601370, 606560, 606563, 606564, 606565,
#         606566, 606568, 606570, 606571, 606576, 606577, 606583, 607163,
#         631749, 631755, 631763, 631782, 631795, 654427, 654437, 654739,
#         654808, 654809, 654810, 654816, 654817, 654818, 654823, 654826,
#         680925, 680935, 681237, 681306, 681307, 681308, 681314, 681315,
#         681316, 681321, 681324, 703332, 703338, 703346, 703365, 703378,
#         728422, 730677, 730680, 730681, 730682, 730683, 730685, 730687,
#         730688, 730693, 730694, 730700]),
# ...

# %%
k_means_predicted=kmeans.predict(df1)

# %%
print(k_means_predicted)
# Out:
# [0 0 0 ... 1 4 1]

# %%
clmns=['job ID', 'event type', 'sceduling class']

# %%
plt.scatter(df1['event_type'],df1['scheduling_class'])

# %%
df1['clusters']=kmeans.labels_

# %%
clmns.extend(['clusters'])

# %%
df1
# Out:
#             job_ID  event_type  scheduling_class  clusters
# 0       6486215124           4                 1         0
# 1       6486208376           4                 2         0
# 2       6486208454           5                 0         0
# 3       6486208583           5                 2         0
# 4       6486201135           4                 2         0
# 5       6486201193           5                 0         0
# 6       6486201261           5                 2         0
# 7       6486157353           4                 0         0
# 8       6486215143           4                 1         0
# 9       6486215873           4                 2         0
# 10      6486215919           5                 0         0
# 11      6486215957           5                 2         0
# 12      6486217697           4                 0         0
# 13      6486211871           3                 1         0
# 14      6486216925           3                 1         0
# ...

# %%
df1.groupby(['clusters','event_type']).count()
# Out:
#                      job_ID  scheduling_class
# clusters event_type
# 0        2                6                 6
#          3             3054              3054
#          4            87815             87815
#          5            63536             63536
# 1        2               22                22
#          3             2943              2943
#          4           137826            137826
#          5            91234             91234
# 2        3                2                 2
#          5               90                90
# 3        2                2                 2
#          3             2339              2339
#          4            92445             92445
#          5            63198             63198
# 4        3               19                19
#          5              246               246
# 5        2                2                 2
#          3             2701              2701
#          4           104593            104593
# ...

# %%
state_office = df1.groupby(['clusters', 'event_type']).agg({'job_ID': 'count'})

# %%
state_office
# Out:
#                      job_ID
# clusters event_type
# 0        2                6
#          3             3054
#          4            87815
#          5            63536
# 1        2               22
#          3             2943
#          4           137826
#          5            91234
# 2        3                2
#          5               90
# 3        2                2
#          3             2339
#          4            92445
#          5            63198
# 4        3               19
#          5              246
# 5        2                2
#          3             2701
#          4           104593
#          5            78652

# %%
state_pcts = state_office.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))

# %%
state_pcts
# Out:
#                         job_ID
# clusters event_type
# 0        2            0.003886
#          3            1.977838
#          4           56.870948
#          5           41.147328
# 1        2            0.009482
#          3            1.268398
#          4           59.401358
#          5           39.320763
# 2        3            2.173913
#          5           97.826087
# 3        2            0.001266
#          3            1.480530
#          4           58.515419
#          5           40.002785
# 4        3            7.169811
#          5           92.830189
# 5        2            0.001076
#          3            1.452557
#          4           56.248521
#          5           42.297847

# %%
df2= state_pcts.rename(columns={'job_ID': 'Ratio of each event type'})
df2
# Out:
#                      Ratio of each event type
# clusters event_type
# 0        2                           0.003886
#          3                           1.977838
#          4                          56.870948
#          5                          41.147328
# 1        2                           0.009482
#          3                           1.268398
#          4                          59.401358
#          5                          39.320763
# 2        3                           2.173913
#          5                          97.826087
# 3        2                           0.001266
#          3                           1.480530
#          4                          58.515419
#          5                          40.002785
# 4        3                           7.169811
#          5                          92.830189
# 5        2                           0.001076
#          3                           1.452557
#          4                          56.248521
# ...

# %%
df4=df2
df4['sum']=state_office
df4
# Out:
#                      Ratio of each event type     sum
# clusters event_type
# 0        2                           0.003886       6
#          3                           1.977838    3054
#          4                          56.870948   87815
#          5                          41.147328   63536
# 1        2                           0.009482      22
#          3                           1.268398    2943
#          4                          59.401358  137826
#          5                          39.320763   91234
# 2        3                           2.173913       2
#          5                          97.826087      90
# 3        2                           0.001266       2
#          3                           1.480530    2339
#          4                          58.515419   92445
#          5                          40.002785   63198
# 4        3                           7.169811      19
#          5                          92.830189     246
# ...

# %%
df1
# Out:
#             job_ID  event_type  scheduling_class  clusters
# 0       6486215124           4                 1         0
# 1       6486208376           4                 2         0
# 2       6486208454           5                 0         0
# 3       6486208583           5                 2         0
# 4       6486201135           4                 2         0
# 5       6486201193           5                 0         0
# 6       6486201261           5                 2         0
# 7       6486157353           4                 0         0
# 8       6486215143           4                 1         0
# 9       6486215873           4                 2         0
# 10      6486215919           5                 0         0
# 11      6486215957           5                 2         0
# 12      6486217697           4                 0         0
# 13      6486211871           3                 1         0
# 14      6486216925           3                 1         0
# ...

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2, n_iter=250).fit_transform(df1.drop(columns='clusters'))

# %%
X_embedded
# Out:
# array([[ 0.38622546,  0.19026566],
#        [ 0.49416405,  0.41354126],
#        [ 0.4953485 ,  0.41353068],
#        ...,
#        [-0.02257853, -0.1749912 ],
#        [ 0.7561822 ,  0.01234064],
#        [-0.0225657 , -0.17499119]], dtype=float32)

# %%
plt.figure(figsize=(15,9))
plt.scatter(X_embedded[:,0],X_embedded[:,1],c=df1['clusters'], cmap='viridis')

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(df1.drop(columns='clusters'))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
new_col=pca.transform(df1.drop(columns='clusters'))

# %%
new_col
# Out:
# array([[-1.25046354e+08,  1.05087560e-01],
#        [-1.25039606e+08,  1.10270330e+00],
#        [-1.25039684e+08, -9.61546403e-01],
#        ...,
#        [ 8.03438699e+07,  1.04581647e+00],
#        [ 1.44498369e+09,  1.12642695e+00],
#        [ 8.03437039e+07,  1.17220132e-01]])

# %%
new_col[:,0]
# Out:
# array([-1.25046354e+08, -1.25039606e+08, -1.25039684e+08, ...,
#         8.03438699e+07,  1.44498369e+09,  8.03437039e+07])

# %%
plt.figure(figsize=(15,9))
plt.scatter(new_col[:,0],new_col[:,1],c=df1['clusters'], cmap='viridis')

# %%
state_office = df1.groupby(['clusters', 'event_type']).agg({'job_ID': 'count'})
