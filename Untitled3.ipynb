# %%
from collections import OrderedDict
import os
from pandas import DataFrame
from glob import glob
import pandas as pd
import csv
from pandas import read_csv
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/home/ubuntu/merged_files/merged_task_events.csv')

# %%
df=df.dropna(subset=['CPU request','memory request'])
df
# Out:
#            CPU request  Unnamed: 0  different machines restriction  \
# 0             0.012500           0                             0.0
# 1             0.012500           1                             0.0
# 2             0.012500           2                             0.0
# 3             0.012500           3                             0.0
# 4             0.012500           4                             0.0
# 5             0.024990           5                             1.0
# 6             0.012500           6                             0.0
# 7             0.012500           7                             0.0
# 8             0.012500           8                             0.0
# 9             0.012500           9                             0.0
# 10            0.012500          10                             0.0
# 11            0.012500          11                             0.0
# 12            0.009369          12                             0.0
# 13            0.012500          13                             0.0
# 14            0.012500          14                             0.0
# 15            0.012500          15                             0.0
# 16            0.012500          16                             0.0
# 17            0.012500          17                             0.0
# 18            0.012500          18                             0.0
# 19            0.012500          19                             0.0
# 20            0.012500          20                             0.0
# 21            0.012500          21                             0.0
# 22            0.012500          22                             0.0
# 23            0.012500          23                             0.0
# 24            0.012500          24                             0.0
# 25            0.015620          25                             0.0
# 26            0.015620          26                             0.0
# 27            0.015620          27                             0.0
# 28            0.015620          28                             0.0
# 29            0.012500          29                             0.0
# ...                ...         ...                             ...
# 200012511     0.024990      233222                             1.0
# 200012512     0.024990      233223                             1.0
# 200012513     0.000625      233224                             0.0
# 200012514     0.000625      233225                             0.0
# 200012515     0.015620      233226                             0.0
# 200012516     0.015620      233227                             0.0
# 200012517     0.015620      233228                             0.0
# 200012518     0.015620      233229                             0.0
# 200012519     0.062500      233230                             0.0
# 200012520     0.062500      233231                             0.0
# 200012521     0.024990      233232                             1.0
# 200012522     0.125000      233233                             0.0
# 200012523     0.125000      233234                             0.0
# 200012524     0.024990      233235                             1.0
# 200012525     0.030240      233236                             0.0
# 200012526     0.030240      233237                             0.0
# 200012527     0.024990      233238                             1.0
# 200012528     0.062500      233239                             0.0
# 200012529     0.062500      233240                             0.0
# 200012530     0.024990      233241                             1.0
# 200012531     0.024990      233242                             1.0
# 200012532     0.062500      233243                             0.0
# 200012533     0.062500      233244                             0.0
# 200012534     0.062500      233245                             0.0
# 200012535     0.024990      233246                             1.0
# 200012536     0.024990      233247                             1.0
# 200012537     0.062500      233248                             0.0
# 200012538     0.062500      233249                             0.0
# 200012539     0.024990      233250                             1.0
# 200012540     0.024990      233251                             1.0
#
#            disk space request  event type      job ID    machine ID  \
# 0                    0.000404           1  6336594489  4.478594e+09
# 1                    0.000404           1  6336594489  2.852052e+06
# 2                    0.000404           1  6336594489  1.437000e+09
# 3                    0.000404           1  6336594489  3.337872e+09
# 4                    0.000404           1  6336594489  3.864352e+07
# 5                    0.000386           4  6360294731  1.272980e+06
# 6                    0.000404           3  6336594489  1.979666e+09
# 7                    0.000404           0  6336594489           NaN
# 8                    0.000404           3  6336594489  4.478629e+09
# 9                    0.000404           0  6336594489           NaN
# 10                   0.000404           3  6336594489  4.500963e+08
# 11                   0.000404           0  6336594489           NaN
# 12                   0.000010           4  6360123328  4.242297e+08
# 13                   0.000404           3  6336594489  1.301715e+06
# 14                   0.000404           0  6336594489           NaN
# 15                   0.000404           1  6336594489  1.301974e+06
# 16                   0.000404           1  6336594489  3.810708e+09
# 17                   0.000404           1  6336594489  6.641442e+06
# 18                   0.000404           1  6336594489  6.725140e+05
# 19                   0.000404           1  6336594489  1.094507e+06
# 20                   0.000404           1  6336594489  3.360559e+08
# 21                   0.000404           1  6336594489  3.813280e+09
# 22                   0.000404           1  6336594489  2.949948e+08
# 23                   0.000404           1  6336594489  5.784322e+06
# 24                   0.000404           1  6336594489  4.820435e+09
# 25                   0.000215           5   515042969           NaN
# 26                   0.000215           0   515042969           NaN
# 27                   0.000215           5   515042969           NaN
# 28                   0.000215           0   515042969           NaN
# 29                   0.000404           3  6336594489  3.701209e+08
# ...                       ...         ...         ...           ...
# 200012511            0.000386           1  6427108405  4.820017e+09
# 200012512            0.000386           1  6427119878  4.820017e+09
# 200012513            0.000008           2  6419322512  5.014378e+08
# 200012514            0.000008           0  6419322512           NaN
# 200012515            0.000309           2  6398455223  5.014378e+08
# 200012516            0.000309           0  6398455223           NaN
# 200012517            0.000309           2  6405351531  5.014378e+08
# 200012518            0.000309           0  6405351531           NaN
# 200012519            0.000270           2  6425729247  5.014378e+08
# 200012520            0.000270           0  6425729247           NaN
# 200012521            0.000386           1  6427084296  5.014378e+08
# 200012522            0.000058           2  6425153943  2.735491e+08
# 200012523            0.000058           0  6425153943           NaN
# 200012524            0.000386           1  6427108405  2.735491e+08
# 200012525            0.000077           2  6426750415  9.796188e+07
# 200012526            0.000077           0  6426750415           NaN
# 200012527            0.000386           1  6427084296  9.796188e+07
# 200012528            0.000193           2  6426468176  9.731931e+08
# 200012529            0.000193           0  6426468176           NaN
# 200012530            0.000386           1  6427106963  9.731931e+08
# 200012531            0.000386           1  6427084296  9.731931e+08
# 200012532            0.000189           4  6426904563  6.565373e+06
# 200012533            0.000193           2  6426468176  1.093967e+06
# 200012534            0.000193           0  6426468176           NaN
# 200012535            0.000386           1  6427084296  1.093967e+06
# 200012536            0.000386           1  6427106963  1.093967e+06
# 200012537            0.000579           2  6426950902  3.085167e+08
# 200012538            0.000579           0  6426950902           NaN
# 200012539            0.000386           1  6427106963  3.085167e+08
# 200012540            0.000386           1  6427084296  3.085167e+08
#
#            memory request  missing info  priority  scheduling class  \
# 0                0.015900           NaN         0                 0
# 1                0.015900           NaN         0                 0
# 2                0.015900           NaN         0                 0
# 3                0.015900           NaN         0                 0
# 4                0.015900           NaN         0                 0
# 5                0.033390           NaN         4                 0
# 6                0.015900           NaN         0                 0
# 7                0.015900           NaN         0                 0
# 8                0.015900           NaN         0                 0
# 9                0.015900           NaN         0                 0
# 10               0.015900           NaN         0                 0
# 11               0.015900           NaN         0                 0
# 12               0.031800           NaN         4                 1
# 13               0.015900           NaN         0                 0
# 14               0.015900           NaN         0                 0
# 15               0.015900           NaN         0                 0
# 16               0.015900           NaN         0                 0
# 17               0.015900           NaN         0                 0
# 18               0.015900           NaN         0                 0
# 19               0.015900           NaN         0                 0
# 20               0.015900           NaN         0                 0
# 21               0.015900           NaN         0                 0
# 22               0.015900           NaN         0                 0
# 23               0.015900           NaN         0                 0
# 24               0.015900           NaN         0                 0
# 25               0.015530           NaN         0                 2
# 26               0.015530           NaN         0                 2
# 27               0.015530           NaN         0                 2
# 28               0.015530           NaN         0                 2
# 29               0.015900           NaN         0                 0
# ...                   ...           ...       ...               ...
# 200012511        0.095460           NaN         4                 0
# 200012512        0.022890           NaN         4                 0
# 200012513        0.000777           NaN         0                 0
# 200012514        0.000777           NaN         0                 0
# 200012515        0.039790           NaN         1                 0
# 200012516        0.039790           NaN         1                 0
# 200012517        0.039790           NaN         1                 0
# 200012518        0.039790           NaN         1                 0
# 200012519        0.031800           NaN         1                 0
# 200012520        0.031800           NaN         1                 0
# 200012521        0.021480           NaN         4                 0
# 200012522        0.095460           NaN         1                 2
# 200012523        0.095460           NaN         1                 2
# 200012524        0.095460           NaN         4                 0
# 200012525        0.006218           NaN         0                 0
# 200012526        0.006218           NaN         0                 0
# 200012527        0.021480           NaN         4                 0
# 200012528        0.031800           NaN         1                 0
# 200012529        0.031800           NaN         1                 0
# 200012530        0.020750           NaN         4                 0
# 200012531        0.021480           NaN         4                 0
# 200012532        0.124300           NaN         4                 0
# 200012533        0.031800           NaN         1                 0
# 200012534        0.031800           NaN         1                 0
# 200012535        0.021480           NaN         4                 0
# 200012536        0.020750           NaN         4                 0
# 200012537        0.031800           NaN         1                 0
# 200012538        0.031800           NaN         1                 0
# 200012539        0.020750           NaN         4                 0
# 200012540        0.021480           NaN         4                 0
#
#            task index     timestamp  \
# 0                 807  1.143154e+12
# 1                2687  1.143154e+12
# 2                5023  1.143154e+12
# 3               18585  1.143154e+12
# 4               19156  1.143154e+12
# 5                 370  1.143154e+12
# 6               12184  1.143154e+12
# 7               12184  1.143154e+12
# 8                 226  1.143154e+12
# 9                 226  1.143154e+12
# 10               3001  1.143154e+12
# 11               3001  1.143154e+12
# 12                 12  1.143154e+12
# 13               7728  1.143154e+12
# 14               7728  1.143154e+12
# 15               3240  1.143155e+12
# 16               6194  1.143155e+12
# 17               6268  1.143155e+12
# 18               7645  1.143155e+12
# 19               7925  1.143155e+12
# 20              14847  1.143155e+12
# 21              15149  1.143155e+12
# 22              18307  1.143155e+12
# 23              18319  1.143155e+12
# 24              18742  1.143155e+12
# 25                  4  1.143155e+12
# 26                  4  1.143155e+12
# 27                 20  1.143155e+12
# 28                 20  1.143155e+12
# 29              18952  1.143155e+12
# ...               ...           ...
# 200012511         341  1.899843e+12
# 200012512         154  1.899843e+12
# 200012513        3391  1.899843e+12
# 200012514        3391  1.899843e+12
# 200012515         915  1.899843e+12
# 200012516         915  1.899843e+12
# 200012517         428  1.899843e+12
# 200012518         428  1.899843e+12
# 200012519        1396  1.899843e+12
# 200012520        1396  1.899843e+12
# 200012521         943  1.899843e+12
# 200012522          12  1.899843e+12
# 200012523          12  1.899843e+12
# 200012524        1222  1.899843e+12
# 200012525        2987  1.899843e+12
# 200012526        2987  1.899843e+12
# 200012527         529  1.899843e+12
# 200012528        1174  1.899843e+12
# 200012529        1174  1.899843e+12
# 200012530         196  1.899843e+12
# 200012531        1753  1.899843e+12
# 200012532         244  1.899843e+12
# 200012533        1771  1.899843e+12
# 200012534        1771  1.899843e+12
# 200012535        1002  1.899843e+12
# 200012536         390  1.899843e+12
# 200012537        1962  1.899843e+12
# 200012538        1962  1.899843e+12
# 200012539         227  1.899843e+12
# 200012540        1930  1.899843e+12
#
#                                                    user
# 0          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 1          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 2          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 3          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 4          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 5          fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 6          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 7          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 8          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 9          EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 10         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 11         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 12         6lpxC7QF83s2DTmzj4eaHKvxedYvdDxy5U+dTtzeENg=
# 13         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 14         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 15         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 16         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 17         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 18         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 19         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 20         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 21         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 22         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 23         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 24         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# 25         /fk1fVcVxZ6iM6gHZzqbIyq56m5zrmHfpdcZ/zzkq4c=
# 26         /fk1fVcVxZ6iM6gHZzqbIyq56m5zrmHfpdcZ/zzkq4c=
# 27         /fk1fVcVxZ6iM6gHZzqbIyq56m5zrmHfpdcZ/zzkq4c=
# 28         /fk1fVcVxZ6iM6gHZzqbIyq56m5zrmHfpdcZ/zzkq4c=
# 29         EWR2JX3J0jkvMGNMIspQtGDDKdHpC+lJouLPdwBkDBE=
# ...                                                 ...
# 200012511  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012512  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012513  pDh86mFzXvkDVFYaKAwsW21bFqbT8oa1/krMRgyUX7o=
# 200012514  pDh86mFzXvkDVFYaKAwsW21bFqbT8oa1/krMRgyUX7o=
# 200012515  +ENeFB0lOVM//Cb4Jl0AY6TiNoKa1ziTUY9PrN23hos=
# 200012516  +ENeFB0lOVM//Cb4Jl0AY6TiNoKa1ziTUY9PrN23hos=
# 200012517  +ENeFB0lOVM//Cb4Jl0AY6TiNoKa1ziTUY9PrN23hos=
# 200012518  +ENeFB0lOVM//Cb4Jl0AY6TiNoKa1ziTUY9PrN23hos=
# 200012519  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012520  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012521  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012522  ALKg5AFdgMwZt3L7ZOLUlG9p6A/mR6Q6XzoU6n0sQmw=
# 200012523  ALKg5AFdgMwZt3L7ZOLUlG9p6A/mR6Q6XzoU6n0sQmw=
# 200012524  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012525  /KpLSln+xsCEsGYWyFCwF3hyiwkbKDISvwa51r2FAqs=
# 200012526  /KpLSln+xsCEsGYWyFCwF3hyiwkbKDISvwa51r2FAqs=
# 200012527  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012528  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012529  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012530  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012531  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012532  N5I2+pqV0s9j+1XwV8fwIxAb8p47z4I3dJ4o2I/RLxQ=
# 200012533  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012534  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012535  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012536  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012537  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012538  Nugr6rX+U6WELDvGY6ars76339mw/Uc2fgD1/rZ6fkA=
# 200012539  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
# 200012540  fJYeclskJqPWsAT6TX/r9X5OiIZpSEb2PBGliYAOMxM=
#
# [200012251 rows x 14 columns]

# %%
from random import randint, sample, seed
seed(83)
sample_moments = sorted(sample(range(250619902823), 200))
snapshot_moment = randint(0, 250619902822)
print (snapshot_moment)
# Out:
# 182602390144

# %%
from collections import OrderedDict
import os
from pandas import DataFrame

tasks_dict = {}
samples_dicts = OrderedDict([])
sample_moments_iterator = iter(sample_moments)
current_sample_moment = next(sample_moments_iterator)
tasks_df = None

# %%
from random import randint, sample, seed
seed(83)
sample_moments = sorted(sample(range(250619902823), 200))
snapshot_moment = randint(0, 250619902822)
print (snapshot_moment)
# Out:
# 182602390144

# %%
machines_dict = {}
sample_moments_iterator = iter(sample_moments)
current_sample_moment = next(sample_moments_iterator)
machines_df = None
samples_dicts = OrderedDict([])

machine_events_csv_colnames=['time', 'machine_id', 'event_type', 'platform_id', 'cpu', 'mem']

for fn in sorted(os.listdir('/home/ubuntu/machine_events')):
    fp = os.path.join('/home/ubuntu/machine_events', fn)
    machine_events_df = pd.read_csv(fp, header=None, index_col=False, compression='gzip', names=machine_events_csv_colnames)
    for index, event in machine_events_df.iterrows():
        
        if current_sample_moment is not None and event['time'] > current_sample_moment:
            tmp_machines_df = DataFrame(list(machines_dict.values()))
            samples_dicts[current_sample_moment]=({     'time' : current_sample_moment,
                                                        'cpu_available' : sum(tmp_machines_df['cpu']), 
                                                         'mem_available' : sum(tmp_machines_df['mem'])})
            try:
                current_sample_moment = next(sample_moments_iterator)
            except StopIteration:
                current_sample_moment = None
                
        if machines_df is None and event['time'] > snapshot_moment: 
            machines_df = DataFrame(list(machines_dict.values()))
            
        if event['event_type'] in [0, 2]:
            machines_dict[event['machine_id']] = { 'time' : event['time'], 
                                                    'machine_id' : event['machine_id'], 
                                                  'cpu' : event['cpu'], 'mem' : event['mem']}
        elif event['event_type'] in [1]:
            del machines_dict[event['machine_id']]

    if machines_df is not None and current_sample_moment is None:
        break
                    
machines_df = DataFrame(list(machines_dict.values()))
samples_df = DataFrame(list(samples_dicts.values()))

print (machines_df)
print
print (samples_df)
print
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-ffa69206e290> in <module>
#       9 for fn in sorted(os.listdir('/home/ubuntu/machine_events')):
#      10     fp = os.path.join('/home/ubuntu/machine_events', fn)
# ---> 11     machine_events_df = pd.read_csv(fp, header=None, index_col=False, compression='gzip', names=machine_events_csv_colnames)
#      12     for index, event in machine_events_df.iterrows():
#      13
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_column_name()
#
# IndexError: list index out of range

# %%
machines_df1 = machines_df.sample(frac =.10)

# %%
machines_df1
# Out:
#         cpu  machine_id     mem           time
# 6807   0.50  4497606319  0.4995              0
# 1161   0.50     1306107  0.4995              0
# 1320   0.50     1340548  0.4995              0
# 1995   0.50     7781238  0.4995              0
# 4489   0.50   351675430  0.4995              0
# 6976   1.00  4820072284  1.0000              0
# 12094  0.50   351642813  0.4995  2342185249678
# 6283   0.25  3739434716  0.2498              0
# 2502   0.50    47057843  0.4995              0
# 7926   0.50  1436548834  0.4995   347711076433
# 10760  0.50     1094786  0.4995  1956474387659
# 4821   0.50   450119653  0.4995              0
# 4099   0.50   336048011  0.2493              0
# 162    0.50      631947  0.4995              0
# 4166   0.50   336061649  0.2493              0
# 578    0.50      905595  0.4995              0
# 9546   0.50   227436437  0.4995  1448375103962
# 6248   0.50  3665453781  0.7490              0
# 5604   0.50  1726343673  0.4995              0
# 7851   0.50   257338293  0.7490   298972148704
# 11836  0.50      711359  0.4995  2250536711747
# 5986   0.50  3004453972  0.4995              0
# 10850  0.50  4100274288  0.4995  1981742632561
# 3418   0.50   294862969  0.2493              0
# 11721  0.50      765537  0.4995  2239286161143
# 3678   0.50   317477953  0.7490              0
# 4502   0.50   352694658  0.4995              0
# 3459   0.50   294927213  0.2493              0
# 430    0.50      711935  0.4995              0
# 658    0.50      988445  0.4995              0
# ...     ...         ...     ...            ...
# 3943   0.50   330266357  0.4995              0
# 1188   0.50     1324986  0.4995              0
# 12003  0.50      486958  0.4995  2314539085940
# 12004  0.50   438722692  0.2493  2314547662189
# 8582   0.50   217525204  0.2493   796459143284
# 6233   0.25  3630727628  0.2498              0
# 9161   0.50   336068307  0.2493  1180791295812
# 8322   0.50    16914032  0.4995   657735348854
# 6023   0.50  3230943988  0.4995              0
# 6774   0.50  4478521935  0.4995              0
# 10408  0.50    97923435  0.4995  1772843429752
# 1668   0.50     6566579  0.4995              0
# 6762   0.50  4477455016  0.4995              0
# 1849   0.50     6608772  0.4995              0
# 3093   0.50   257409273  0.7490              0
# 9317   0.50  3416612140  0.7490  1295421736504
# 5720   0.50  2129474533  0.4995              0
# 8335   0.50   226252471  0.2493   671141358397
# 9619   0.50   587055228  0.2493  1486992981872
# 8482   0.50   336047452  0.2493   767725505819
# 5736   0.50  2188987289  0.4995              0
# 8699   0.50   317488607  0.7490   879015755931
# 1241   0.50     1335575  0.2493              0
# 1023   0.50     1272676  0.4995              0
# 10848  0.50      603107  0.4995  1977426959659
# 9351   0.50   376293619  0.4995  1308066250455
# 5854   0.50  2568530361  0.2493              0
# 3207   0.50   257512310  0.2493              0
# 6386   0.50  3938710085  0.4995              0
# 8576   0.50   697012737  0.4995   790782580919
#
# [1249 rows x 4 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
#ax.plot(samples_df['time'], samples_df['cpu_requested'], label='cpu requested')
ax.plot(samples_df['time'], samples_df['cpu_available'], label='cpu available')
#ax.plot(samples_df['time'], samples_df['mem_requested'], label='mem requested')
ax.plot(samples_df['time'], samples_df['mem_available'], label='mem available')
plt.xlim(min(samples_df['time']), max(samples_df['time']))
plt.legend()
plt.show()

# %%
task_usage_csv_colnames=['starttime', 'endtime', 'job_id', 'task_idx', 'machine_id', 'cpu_usage', 'mem_usage', 
                         'assigned_mem', 'unmapped_cache_usage', 'page_cache_usage', 'max_mem_usage', 'disk_io_time', 
                         'max_disk_space', 'max_cpu_usage', 'max_disk_io_time', 'cpi', 'mai', 'sampling_rate', 'agg_type']

for moment in samples_dicts:
    samples_dicts[moment].update({'cpu_usage' : 0.0, 'mem_usage' : 0.0})
    
for task in tasks_dict:
    tasks_dict[task].update({'cpu_usage' : 0.0, 'mem_usage' : 0.0, 'in_events' : True, 'in_usage' : False})
    

for fn in sorted(os.listdir('task_usage')):

    fp = os.path.join('task_usage', fn)
    task_usage_df = read_csv(fp, header=None, index_col=False, names=task_usage_csv_colnames)

    laststart = max(task_usage_df['starttime'])
    if laststart > max(sample_moments) and laststart > snapshot_moment:
        break
        
    for moment in samples_dicts:
        task_usage_moment_df = task_usage_df[(task_usage_df['starttime'] <= moment) & 
                                             (moment <= task_usage_df['endtime'])]
        samples_dicts[moment]['cpu_usage'] += sum(task_usage_moment_df['cpu_usage'])
        samples_dicts[moment]['mem_usage'] += sum(task_usage_moment_df['mem_usage'])

    task_usage_snapshot_df = task_usage_df[(task_usage_df['starttime'] <= snapshot_moment) &
                                           (snapshot_moment <= task_usage_df['endtime'])]
    for index, usage in task_usage_snapshot_df.iterrows():
        task_id = (usage['job_id'], usage['task_idx'])
        if task_id in tasks_dict:
            tasks_dict[task_id].update({'cpu_usage' : usage['cpu_usage'], 'mem_usage' : usage['mem_usage'], 
                                        'in_events': True, 'in_usage' : True})
        else:
            tasks_dict[task_id] = {'cpu_requested' : 0.0, 'mem_requested' : 0.0, 
                                   'cpu_usage' : usage['cpu_usage'], 'mem_usage' : usage['mem_usage'],
                                   'in_events' : False, 'in_usage' : True}


samples_df = DataFrame(list(samples_dicts.values()))
print (samples_df)
tasks_df = DataFrame(list(tasks_dict.values()))
print (tasks_df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-e82ef95c7bef> in <module>
#      13
#      14     fp = os.path.join('task_usage', fn)
# ---> 15     task_usage_df = read_csv(fp, header=None, index_col=False, names=task_usage_csv_colnames)
#      16
#      17     laststart = max(task_usage_df['starttime'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_column_name()
#
# IndexError: list index out of range
